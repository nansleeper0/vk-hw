# %% [markdown]
# # 🧮 Домашнее задание 7. Семинар 7
# ## Курс: *Алгоритмы и структуры данных*
# ### Осень 2025
#
# ---
# **Автор:** Артём Канаев
# ---
#
# ## 📋 Содержание
#
#
#  🔹 [Задача №1. Поиск компонент связности](#task1)
#  🔹 [Задача №2. Поиск цикла в графе](#task2)
#  🔹 [Задача №3. Является ли граф деревом](#task3)
#  🔹 [Задача №4. Алгоритм Дейкстры](#task4)
#  🔹 [Задача №5. Проверка на двудольность](#task5)
#
#
#
#
# > 💡 *Все остальные файлы доступны в GitHub-репозитории:*
# > [https://github.com/nansleeper0/vk-hw](https://github.com/nansleeper0/vk-hw)

# %% [markdown]
# <a id='task1'></a>
# ## 🧩 Задача №1. Поиск компонент связности
#
# ---
#
# ### 📘 Описание
#
# Дан граф. Необходимо подсчитать
# количество компонент связности.

# %%
def find_connected_components(graph):
    visited = {v: False for v in graph}
    connected_components = []

    for v in graph:
        if not visited[v]:
            component = []
            dfs(graph, v, visited, component)
            connected_components.append(component)

    return connected_components


def dfs(graph, v, visited, component):
    visited[v] = True
    component.append(v)

    for u in graph[v]:
        if not visited[u]:
            dfs(graph, u, visited, component)

# %%
def dfs(graph, v, visited, color):
    visited[v] = color
    for u in graph[v]:
        if visited[u] == 0:
            dfs(graph, u, visited, color)


def find_connected_components(graph):
    visited = {v: 0 for v in graph}
    color = 0

    for v in graph:
        if visited[v] == 0:
            color += 1
            dfs(graph, v, visited, color)

    return visited

# %% [markdown]
# <a id='task2'></a>
# ## 🧩 Задача №2. Поиск цикла в графе
#
# ---
#
# ### 📘 Описание
# Дан граф в виде списка вершин. Необходимо понять, есть ли
# в этом графе цикл
#
# ---

# %%
def has_cycle(graph):
    visited = set()
    for vertex in graph:
        if vertex not in visited:
            if dfs(graph, vertex, parent=None, visited=visited):
                return True
    return False


def dfs(graph, vertex, parent, visited):
    visited.add(vertex)

    for neighbor in graph[vertex]:
        if neighbor != parent:
            if neighbor in visited:
                return True
            if dfs(graph, neighbor, vertex, visited):
                return True

    return False

# %% [markdown]
# <a id='task3'></a>
# ## 🧩 Задача №3. Является ли граф деревом
#
# ---
#
# ### 📘 Описание
#
# Является ли граф деревом
#
# ---

# %%
from collections import deque

def is_tree(graph, start):
    visited = set()
    queue = deque([start])
    parent = {start: None}

    while queue:
        vertex = queue.popleft()
        visited.add(vertex)

        for neighbor in graph[vertex]:
            if neighbor not in visited:
                if neighbor not in parent:
                    queue.append(neighbor)
                    parent[neighbor] = vertex
            else:
                if parent[vertex] != neighbor:
                    return False

    return len(visited) == len(graph)

# %% [markdown]
# <a id='task4'></a>
# ## 🧩 Задача №4.Алгоритм Дейкстры
# ---
#
# ### 📘 Описание
#
# Дано некоторое число n. Необходимо создать треугольник
# Паскаля состоящего из n строк
#
# ---

# %%
import heapq

def dijkstra(graph, start):
    distances = {vertex: float('inf') for vertex in graph}
    priority_queue = [(0, start)]

    while priority_queue:
        current_distance, current_vertex = heapq.heappop(priority_queue)

        if current_distance > distances[current_vertex]:
            continue

        for neighbor, weight in graph[current_vertex].items():
            distance = current_distance + weight

            if distance < distances[neighbor]:
                distances[neighbor] = distance
                heapq.heappush(priority_queue, (distance, neighbor))

    return distances

# %% [markdown]
# <a id='task5'></a>
# ## 🧩 Задача №5. Проверка на двудольность
#
# ---
#
# ### 📘 Описание
#
# Дан неориентированный граф. Необходимо написать
# функцию, которая вернет true, если граф является
# двудольным.
#
# ---

# %%
from collections import deque

def is_bipartite(graph):
    n = len(graph)
    colors = [0] * n

    def bfs(start):
        queue = deque([start])

        while queue:
            node = queue.popleft()
            for neighbor in graph[node]:
                if colors[neighbor] == 0:
                    colors[neighbor] = -colors[node]
                    queue.append(neighbor)
                elif colors[neighbor] == colors[node]:
                    return False
        return True

    for i in range(n):
        if colors[i] == 0:
            if not bfs(i):
                return False

    return True

# %%
def is_bipartite(graph):
    n = len(graph)
    colors = [0] * n

    def dfs(node, c):
        colors[node] = c
        for neighbor in graph[node]:
            if colors[neighbor] == 0:
                if not dfs(neighbor, -c):
                    return False
            elif colors[neighbor] == colors[node]:
                return False
        return True

    for i in range(n):
        if colors[i] == 0:
            if not dfs(i, 1):
                return False

    return True

# %%
import sys

def coinChange(coins, amount):
    if amount == 0:
        return 0
    if amount < 0:
        return -1

    min_coins = sys.maxsize

    for coin in coins:
        res = coinChange(coins, amount - coin)
        if res >= 0 and res < min_coins:
            min_coins = res + 1

    if min_coins == sys.maxsize:
        return -1

    return min_coins

# %%
def coin_change(coins, amount, cache=None):
    if cache is None:
        cache = {}

    if amount == 0:
        return 0
    if amount < 0:
        return -1
    if amount in cache:
        return cache[amount]

    min_coins = sys.maxsize

    for coin in coins:
        res = coin_change(coins, amount - coin, cache)
        if res >= 0 and res < min_coins:
            min_coins = res + 1

    if min_coins == sys.maxsize:
        cache[amount] = -1
    else:
        cache[amount] = min_coins

    return cache[amount]

# %%
def coinChange(coins, amount):
    dp = [sys.maxsize] * (amount + 1)
    dp[0] = 0

    for i in range(1, amount + 1):
        for coin in coins:
            if coin <= i:
                dp[i] = min(dp[i], dp[i - coin] + 1)

    if dp[amount] == sys.maxsize:
        return -1
    return dp[amount]

# %%
def longestPalindrome(s):
    currentMaxLeft = 0
    currentMaxRight = 0

    def expandAroundCenter(l, r):
        nonlocal currentMaxLeft, currentMaxRight
        while l >= 0 and r < len(s) and s[l] == s[r]:
            if (r - l) > (currentMaxRight - currentMaxLeft):
                currentMaxLeft = l
                currentMaxRight = r
            l -= 1
            r += 1

    for i in range(len(s)):
        expandAroundCenter(i, i)
        expandAroundCenter(i, i + 1)

    return s[currentMaxLeft:currentMaxRight + 1]

# %%
def longestPalindrome(s):
    n = len(s)
    if n == 0:
        return ""

    dp = [[False] * n for _ in range(n)]

    start = 0
    max_len = 1

    for i in range(n):
        dp[i][i] = True

    for i in range(n - 1):
        if s[i] == s[i + 1]:
            dp[i][i + 1] = True
            start = i
            max_len = 2

    for length in range(3, n + 1):
        for i in range(n - length + 1):
            j = i + length - 1
            if s[i] == s[j] and dp[i + 1][j - 1]:
                dp[i][j] = True
                start = i
                max_len = length

    return s[start:start + max_len]
